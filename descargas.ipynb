# %% [markdown]
# la librería urllib es útil para correr notebooks de la web

# %%
from urllib.request import urlretrieve

# %%
urlretrieve("https://github.com/seap-udea/meccel-clase-profesor/raw/refs/heads/main/CuadernoCeleste-VirialRelajacion.ipynb?authuser=0","virial.ipynb")
# Out:
# ('virial.ipynb', <http.client.HTTPMessage at 0x7607af6736e0>)
